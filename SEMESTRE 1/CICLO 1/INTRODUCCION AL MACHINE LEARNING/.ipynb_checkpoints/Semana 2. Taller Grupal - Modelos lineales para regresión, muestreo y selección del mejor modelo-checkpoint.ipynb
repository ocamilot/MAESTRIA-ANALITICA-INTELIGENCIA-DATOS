# %%
import pandas as pd

ruta_archivo = 'Users/ocamilot/Downloads/Hitters.csv'
# Out:
# /var/folders/4t/gjw0glxj55s27z96j8ljprn40000gs/T/ipykernel_46008/3069631303.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
datos = pd.read_csv(ruta_archivo)
datos
# Out:
#             Unnamed: 0  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 0       -Andy Allanson    293    66      1    30   29     14      1     293
# 1          -Alan Ashby    315    81      7    24   38     39     14    3449
# 2         -Alvin Davis    479   130     18    66   72     76      3    1624
# 3        -Andre Dawson    496   141     20    65   78     37     11    5628
# 4    -Andres Galarraga    321    87     10    39   42     30      2     396
# ..                 ...    ...   ...    ...   ...  ...    ...    ...     ...
# 317      -Willie McGee    497   127      7    65   48     37      5    2703
# 318   -Willie Randolph    492   136      5    76   50     94     12    5511
# 319    -Wayne Tolleson    475   126      3    61   43     52      6    1700
# 320     -Willie Upshaw    573   144      9    85   60     78      8    3198
# 321     -Willie Wilson    631   170      9    77   44     31     11    4908
#
# ...

# %%
datos = datos.select_dtypes(exclude=['object'])
datos
# Out:
#      AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  \
# 0      293    66      1    30   29     14      1     293     66       1
# 1      315    81      7    24   38     39     14    3449    835      69
# 2      479   130     18    66   72     76      3    1624    457      63
# 3      496   141     20    65   78     37     11    5628   1575     225
# 4      321    87     10    39   42     30      2     396    101      12
# ..     ...   ...    ...   ...  ...    ...    ...     ...    ...     ...
# 317    497   127      7    65   48     37      5    2703    806      32
# 318    492   136      5    76   50     94     12    5511   1511      39
# 319    475   126      3    61   43     52      6    1700    433       7
# 320    573   144      9    85   60     78      8    3198    857      97
# 321    631   170      9    77   44     31     11    4908   1457      30
#
#      CRuns  CRBI  CWalks  PutOuts  Assists  Errors  Salary
# ...

# %%
datos = datos.dropna()
datos
# Out:
#      AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  \
# 1      315    81      7    24   38     39     14    3449    835      69
# 2      479   130     18    66   72     76      3    1624    457      63
# 3      496   141     20    65   78     37     11    5628   1575     225
# 4      321    87     10    39   42     30      2     396    101      12
# 5      594   169      4    74   51     35     11    4408   1133      19
# ..     ...   ...    ...   ...  ...    ...    ...     ...    ...     ...
# 317    497   127      7    65   48     37      5    2703    806      32
# 318    492   136      5    76   50     94     12    5511   1511      39
# 319    475   126      3    61   43     52      6    1700    433       7
# 320    573   144      9    85   60     78      8    3198    857      97
# 321    631   170      9    77   44     31     11    4908   1457      30
#
#      CRuns  CRBI  CWalks  PutOuts  Assists  Errors  Salary
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Ejemplo de datos (reemplaza esto con tus datos reales)
datos = np.random.randn(1000)

# Crear un histograma
plt.hist(datos, bins=30, color='blue', edgecolor='black')
plt.title('Histograma de Datos')
plt.xlabel('Valores')
plt.ylabel('Frecuencia')
plt.show()

datos
# Out:
# array([-1.19284616e+00,  1.60487812e-02,  1.45207888e+00, -2.88967781e-01,
#        -3.70011602e-02,  9.69069793e-01, -2.64315543e-01,  3.46976039e-01,
#         3.63618058e+00,  1.81120093e+00, -4.11682490e-02,  1.21010058e+00,
#        -1.79406951e-01,  9.26607935e-01,  6.73019103e-01,  1.94353713e+00,
#        -8.59806379e-02, -9.55838751e-01,  1.27544263e+00, -2.04363189e-01,
#         1.56543261e+00,  1.88274782e+00,  1.24245650e-01,  8.20272833e-01,
#         3.63431203e-01,  9.71711854e-02, -1.33052910e-01, -1.10454745e+00,
#        -1.54350734e+00, -8.08273449e-01, -2.69356165e+00,  7.54151587e-01,
#        -1.57529560e+00, -2.82041943e-01, -1.09807425e-01, -1.40764219e+00,
#         1.07335884e-01, -1.04859905e+00, -9.18991600e-01, -5.66997283e-01,
#        -2.52757609e-01,  9.88997475e-01,  5.62632911e-01, -2.10039187e+00,
#         9.15859114e-01,  1.66018195e-01, -4.90821027e-01,  7.20418601e-01,
# ...
