# %% [markdown]
# ![Captura de pantalla 2023-08-02 a la(s) 1.00.15 p.m..png](data:image/png;base64,...)

# %% [markdown]
# #Librerias

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Importar funciones para crear las graficas pp plot y qq plot

# %%
from funciones_qq_pp_plot import*

#Funciones dentro del archivo funcioneschicuadrado_continuas.py:

# PP_QQ_plot_normal(data,media="estimado",desvesta="estimado"): Plots a QQ plot and PP plot for a normal probability distribution.
# PP_QQ_plot_lognormal(data,media="estimado",desvesta="estimado"): Plots a QQ plot and PP plot for a lognormal probability distribution.
# PP_QQ_plot_exponential(data,tasa="estimado"): Plots a QQ plot and PP plot for an exponential probability distribution.
# PP_QQ_plot_uniform(data,minimo="estimado",maximo="estimado"): Plots a QQ plot and PP plot for a uniform probability distribution.
# PP_QQ_plot_triangular(data,minimo="estimado",maximo="estimado",moda="estimado"): Plots a QQ plot and PP plot for a triangular probability distribution.
# PP_QQ_plot_gamma(data,media="estimado",varianza="estimado"): Plots a QQ plot and PP plot for a gamma probability distribution.
# PP_QQ_plot_weibull(data,forma="estimado",escala="estimado"): Plots a QQ plot and PP plot for a Weibull probability distribution.

# %% [markdown]
# # Importar los datos

# %%
# Importar datos con el archivo de excel cargado a GoogleColab
""" NOTA: Cambie el nombre de acuerdo con el nombre del archivo de Excel: """
df = pd.read_excel('Datos_TEA.xlsx')
series = np.array(df).flatten()
series
# Out:
# array([0.19 , 0.46 , 0.29 , 0.135, 0.103, 0.881, 0.025, 0.503, 0.044,
#        0.157, 1.133, 0.094, 0.156, 0.46 , 0.183, 0.019, 0.351, 0.008,
#        0.232, 0.075, 0.003, 0.112, 0.299, 0.19 , 0.019, 0.258, 0.032,
#        0.351, 0.182, 0.547, 0.025, 1.49 , 0.133, 0.081, 0.729, 0.254,
#        0.125, 0.702, 0.578, 0.557, 0.765, 0.194, 0.589, 0.007, 0.925,
#        0.585, 0.327, 0.073, 0.325, 0.536])

# %% [markdown]
# # **Gráficas para distribuciones continuas**

# %% [markdown]
# **Gráficas para una distribución normal**

# %%
PP_QQ_plot_normal(series,media="estimado",desvesta="estimado")
# Out:
# Parámetro estimado: Media = 0.32984
# Parámetro estimado: Desviación Estándar = 0.31781783209882986

# %% [markdown]
# **Gráficas para una distribución lognormal**

# %%
PP_QQ_plot_lognormal(series,media="estimado",desvesta="estimado")
# Out:
# Parámetro estimado (normal asociada): Media = -1.7488176021689237
# Parámetro estimado (normal asociada): Desviación Estándar = 1.3811369056466682

# %% [markdown]
# **Gráficas para una distribución exponencial**

# %%
PP_QQ_plot_exponential(series,tasa="estimado")
# Out:
# Parámetro estimado: Tasa = 3.0317729808391944

# %% [markdown]
# **Gráficas para una distribución uniforme**

# %%
#Con parámetros estimados
PP_QQ_plot_uniform(series,minimo="estimado",maximo="estimado")
#Con parámetros establecidos por el usuario
PP_QQ_plot_uniform(series,minimo=20,maximo=40)
# Out:
# Parámetro estimado: a = 0.003
# Parámetro estimado: b = 1.49

# %% [markdown]
# **Gráficas para una distribución triangular**

# %%
PP_QQ_plot_triangular(series,minimo="estimado",maximo="estimado",moda="estimado")
# Out:
# Parámetro estimado: a = 0.003
# Parámetro estimado: b = 1.49
# Parámetro estimado: c = 0.19

# %% [markdown]
# **Gráficas para una distribución gamma**

# %%
PP_QQ_plot_gamma(series,media="estimado",varianza="estimado")
# Out:
# Parámetro estimado: Media = 0.32984
# Parámetro estimado: Varianza = 0.1010081744

# %% [markdown]
# **Gráficas para una distribución weibull**

# %%
PP_QQ_plot_weibull(series,forma="estimado",escala="estimado")
# Out:
# Parámetro estimado: Escala = 0.32412872053856434
# Parámetro estimado: Forma = 0.959594854376169
