# %% [markdown]
# ![Captura de pantalla 2023-08-02 a la(s) 1.05.50 p.m..png](data:image/png;base64,...)

# %% [markdown]
# # Librerias

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Importar funciones para la prueba Chi cuadrado

# %%
from funcioneschicuadrado_continuas import*

#Funciones dentro del archivo funcioneschicuadrado_continuas.py:

# chi_square_normal_goodness_of_fit(data,media="estimado",desvesta="estimado",r=2): Performs a Chi-square goodness of fit test for a normal probability distribution.
# chi_square_lognormal_goodness_of_fit(data,media="estimado",desvesta="estimado",r=2): Performs a Chi-square goodness of fit test for a lognormal probability distribution.
# chi_square_exponential_goodness_of_fit(data,tasa="estimado",r=1): Performs a Chi-square goodness of fit test for an exponential probability distribution.
# chi_square_uniform_goodness_of_fit(data,minimo="estimado",maximo="estimado",r=2):Performs a Chi-square goodness of fit test for a uniform probability distribution.
# chi_square_triangular_goodness_of_fit(data,minimo="estimado",maximo="estimado",moda="estimado",r=3):Performs a Chi-square goodness of fit test for a triangular probability distribution.
# chi_square_gamma_goodness_of_fit(data,media="estimado",varianza="estimado",r=2): Performs a Chi-square goodness of fit test for a gamma probability distribution.
# chi_square_weibull_goodness_of_fit(data,forma="estimado",escala="estimado",r=2): Performs a Chi-square goodness of fit test for a Weibull probability distribution.

# %% [markdown]
# # Importar los datos

# %%
# Importar datos con el archivo de excel cargado a GoogleColab
df = pd.read_excel('Datos_TEA.xlsx')
data = np.array(df).flatten()
data
# Out:
# array([0.19 , 0.46 , 0.29 , 0.135, 0.103, 0.881, 0.025, 0.503, 0.044,
#        0.157, 1.133, 0.094, 0.156, 0.46 , 0.183, 0.019, 0.351, 0.008,
#        0.232, 0.075, 0.003, 0.112, 0.299, 0.19 , 0.019, 0.258, 0.032,
#        0.351, 0.182, 0.547, 0.025, 1.49 , 0.133, 0.081, 0.729, 0.254,
#        0.125, 0.702, 0.578, 0.557, 0.765, 0.194, 0.589, 0.007, 0.925,
#        0.585, 0.327, 0.073, 0.325, 0.536])

# %% [markdown]
# # **Pruebas chi-cuadrado con distribuciones continuas**

# %% [markdown]
# **Función Chi-Cuadrado para una distribución normal**

# %%
chi_square_normal_goodness_of_fit(data,media="estimado",desvesta="estimado",r=2)
# Out:
# Parámetro estimado: Media = 0.32984
# Parámetro estimado: Desviación Estándar = 0.31781783209882986
# Chi-squared statistic: 22.000000000000014
# p-value: 0.0025404139700435646

# %% [markdown]
# **Función Chi-Cuadrado para una distribución lognormal**

# %%
chi_square_lognormal_goodness_of_fit(data,media="estimado",desvesta="estimado",r=2)
# Out:
# Parámetro estimado (lognormal asociada): Media = -1.7488176021689237
# Parámetro estimado (lognormal asociada): Desviación Estándar = 1.3811369056466682
# Chi-squared statistic: 11.200000000000017
# p-value: 0.1301299172840349

# %% [markdown]
# **Función Chi-Cuadrado para una distribución exponencial**

# %%
chi_square_exponential_goodness_of_fit(data,tasa="estimado",r=1)
# Out:
# Parámetro estimado: Tasa = 3.0317729808391944
# Chi-squared statistic: 6.4000000000000075
# p-value: 0.6025197244055565

# %% [markdown]
# **Función Chi-Cuadrado para una distribución uniforme**

# %%
chi_square_uniform_goodness_of_fit(data,minimo="estimado",maximo="estimado",r=2)
# Out:
# Parámetro estimado: a = 0.003
# Parámetro estimado: b = 1.49
# Chi-squared statistic: 62.00000000000001
# p-value: 6.011358077984141e-11

# %% [markdown]
# **Función Chi-Cuadrado para una distribución triangular**

# %%
chi_square_triangular_goodness_of_fit(data,minimo="estimado",maximo="estimado",moda="estimado",r=3)
# Out:
# Parámetro estimado: a = 0.003
# Parámetro estimado: b = 1.49
# Parámetro estimado: c = 0.19
# Chi-squared statistic: 63.29562887582039
# p-value: 9.607536988198717e-12

# %% [markdown]
# **Función Chi-Cuadrado para una distribución gamma**

# %%
chi_square_gamma_goodness_of_fit(data,media="estimado",varianza="estimado",r=2)
# Out:
# Parámetro estimado: Media = 0.32984
# Parámetro estimado: Varianza = 0.1010081744
# Chi-squared statistic: 60.17695392794838
# p-value: 1.3915968377631316e-10

# %% [markdown]
# **Función Chi-Cuadrado para una distribución weibull**

# %%
chi_square_weibull_goodness_of_fit(data,forma="estimado",escala="estimado",r=2)
# Out:
# Parámetro estimado: Escala = 0.32412872053856434
# Parámetro estimado: Forma = 0.959594854376169
# Chi-squared statistic: 7.305296119509225
# p-value: 0.3977995586758347
